# %%
# Import modules
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn import preprocessing
train = pd.read_csv('../data/train.csv', index_col=0)
train_clean = pd.read_csv('../data/train_clean.csv', index_col=0)

# %%
#Create building age and remodel age columns
building_age = 2019-train[['YearBuilt']]
re_age = 2019-train[['YearRemodAdd']]
train = train.assign(building_age=building_age, re_age=re_age)

# %%
#re_age-building_age
from sklearn.linear_model import LinearRegression
lm = LinearRegression(normalize=True)
lm.fit(train[['re_age']], train['building_age'])
print('intercept %.2f' %(lm.intercept_))
print('slope %.2f' %(lm.coef_))
print('R-Squared %.2f' %(lm.score(train[['re_age']],train['building_age'])))
print('RSS %.2f' %(np.sum((train['building_age'] - lm.predict(train[['re_age']]))**2)))
train.plot.scatter(x='re_age', y='building_age')
# Out:
# intercept 18.13
# slope 0.87
# R-Squared 0.35
# RSS 863133.68

# %%
#normalize
nor_reage = preprocessing.scale(train['re_age'])
nor_bage = preprocessing.scale(train['building_age'])
# Out:
# /Users/jasonwang/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)

# %%
#re_age-GrLivArea
from sklearn.linear_model import LinearRegression
lm2 = LinearRegression()
lm2.fit(train[['re_age']], train['GrLivArea'])
print('intercept %.2f' %(lm2.intercept_))
print('slope %.2f' %(lm2.coef_))
print('R-Squared %.2f' %(lm2.score(train[['re_age']],train['GrLivArea'])))
print('RSS %.2f' %(np.sum((train['GrLivArea'] - lm.predict(train[['re_age']]))**2)))
train.plot.scatter(x='re_age', y='GrLivArea')
# Out:
# intercept 1765.15
# slope -7.31
# R-Squared 0.08
# RSS 3556415727.05

# %%
#re_age-OverallQual
from sklearn.linear_model import LinearRegression
lm3 = LinearRegression()
lm3.fit(train[['re_age']], train['OverallQual'])
print('intercept %.2f' %(lm3.intercept_))
print('slope %.2f' %(lm3.coef_))
print('R-Squared %.2f' %(lm3.score(train[['re_age']],train['OverallQual'])))
print('RSS %.2f' %(np.sum((train['OverallQual'] - lm.predict(train[['re_age']]))**2)))
train.plot.scatter(x='re_age', y='OverallQual')
# Out:
# intercept 7.36
# slope -0.04
# R-Squared 0.30
# RSS 3040984.91

# %%
#re_age-LotArea
from sklearn.linear_model import LinearRegression
lm4 = LinearRegression()
lm4.fit(train[['re_age']], train['LotArea'])
print('intercept %.2f' %(lm4.intercept_))
print('slope %.2f' %(lm4.coef_))
print('R-Squared %.4f' %(lm4.score(train[['re_age']],train['LotArea'])))
print('RSS %.2f' %(np.sum((train['LotArea'] - lm.predict(train[['re_age']]))**2)))
train.plot.scatter(x='re_age', y='LotArea')
# Out:
# intercept 10744.37
# slope -6.67
# R-Squared 0.0002
# RSS 305380355913.94

# %%
#building_age-GrLivArea
from sklearn.linear_model import LinearRegression
lm5 = LinearRegression()
lm5.fit(train[['building_age']], train['GrLivArea'])
print('intercept %.2f' %(lm5.intercept_))
print('slope %.2f' %(lm5.coef_))
print('R-Squared %.2f' %(lm4.score(train[['building_age']],train['GrLivArea'])))
print('RSS %.2f' %(np.sum((train['GrLivArea'] - lm.predict(train[['building_age']]))**2)))
train.plot.scatter(x='building_age', y='GrLivArea')
# Out:
# intercept 1680.73
# slope -3.46
# R-Squared -287.74
# RSS 3506710319.11

# %%
#building_age-OverallQual
from sklearn.linear_model import LinearRegression
lm6 = LinearRegression()
lm6.fit(train[['building_age']], train['OverallQual'])
print('intercept %.2f' %(lm6.intercept_))
print('slope %.2f' %(lm6.coef_))
print('R-Squared %.2f' %(lm4.score(train[['building_age']],train['OverallQual'])))
print('RSS %.2f' %(np.sum((train['OverallQual'] - lm.predict(train[['building_age']]))**2)))
train.plot.scatter(x='building_age', y='OverallQual')
# Out:
# intercept 7.35
# slope -0.03
# R-Squared -56827481.57
# RSS 5231854.64

# %%
#building_age-LotArea
from sklearn.linear_model import LinearRegression
lm7 = LinearRegression()
lm7.fit(train[['building_age']], train['LotArea'])
print('intercept %.2f' %(lm7.intercept_))
print('slope %.2f' %(lm7.coef_))
print('R-Squared %.4f' %(lm4.score(train[['building_age']],train['LotArea'])))
print('RSS %.2f' %(np.sum((train['LotArea'] - lm.predict(train[['building_age']]))**2)))
train.plot.scatter(x='building_age', y='LotArea')
# Out:
# intercept 10741.26
# slope -4.70
# R-Squared 0.0001
# RSS 305024228336.92

# %%
#GrLivArea-OverallQual
from sklearn.linear_model import LinearRegression
lm8 = LinearRegression()
lm8.fit(train[['GrLivArea']], train['OverallQual'])
print('intercept %.2f' %(lm8.intercept_))
print('slope %.4f' %(lm8.coef_))
print('R-Squared %.2f' %(lm4.score(train[['GrLivArea']],train['OverallQual'])))
print('RSS %.2f' %(np.sum((train['OverallQual'] - lm.predict(train[['GrLivArea']]))**2)))
train.plot.scatter(x='GrLivArea', y='OverallQual')
# Out:
# intercept 3.73
# slope 0.0016
# R-Squared -6629991.70
# RSS 2870606224.17

# %%
#GrLivArea-LotArea
from sklearn.linear_model import LinearRegression
lm9 = LinearRegression()
lm9.fit(train[['GrLivArea']], train['LotArea'])
print('intercept %.2f' %(lm9.intercept_))
print('slope %.2f' %(lm9.coef_))
print('R-Squared %.2f' %(lm4.score(train[['GrLivArea']],train['LotArea'])))
print('RSS %.2f' %(np.sum((train['LotArea'] - lm.predict(train[['GrLivArea']]))**2)))
train.plot.scatter(x='GrLivArea', y='LotArea')
# Out:
# intercept 2942.88
# slope 5.00
# R-Squared -1.29
# RSS 265317965102.22

# %%
#OverallQual-LotArea
from sklearn.linear_model import LinearRegression
lm10 = LinearRegression()
lm10.fit(train[['OverallQual']], train['LotArea'])
print('intercept %.2f' %(lm10.intercept_))
print('slope %.2f' %(lm10.coef_))
print('R-Squared %.4f' %(lm4.score(train[['OverallQual']],train['LotArea'])))
print('RSS %.2f' %(np.sum((train['LotArea'] - lm.predict(train[['OverallQual']]))**2)))
train.plot.scatter(x='OverallQual', y='LotArea')
# Out:
# intercept 5859.31
# slope 763.61
# R-Squared -0.0005
# RSS 306113168065.29
